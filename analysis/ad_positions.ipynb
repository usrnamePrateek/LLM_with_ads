# %%
import pandas as pd

# %%
df_seman = pd.read_csv("/home/gpuuser7/gpuuser7_a/prateek/LLM_with_ads/data/processed/generation/query_semantic_paragraphs.csv")
df_ads = pd.read_csv("/home/gpuuser7/gpuuser7_a/prateek/LLM_with_ads/data/processed/generation/query_ad_positions.csv")

# %%
df_ads.head(10)
# Out:
#                                      id  \
# 0  c4b9710c-8d64-4bee-a0b0-94637ae4cc65
# 1  c4b9710c-8d64-4bee-a0b0-94637ae4cc65
# 2  c4b9710c-8d64-4bee-a0b0-94637ae4cc65
# 3  c4b9710c-8d64-4bee-a0b0-94637ae4cc65
# 4  4a4380bb-bbdb-495f-8e09-39a08d88a28f
# 5  4a4380bb-bbdb-495f-8e09-39a08d88a28f
# 6  4a4380bb-bbdb-495f-8e09-39a08d88a28f
# 7  4a4380bb-bbdb-495f-8e09-39a08d88a28f
# 8  40f981ca-cca6-4e2a-a48c-d10d51884efe
# 9  40f981ca-cca6-4e2a-a48c-d10d51884efe
#
#                                                query  \
# 0                      Compare Tormenta20 with DnD5e
# 1                      Compare Tormenta20 with DnD5e
# 2                      Compare Tormenta20 with DnD5e
# 3                      Compare Tormenta20 with DnD5e
# 4  What about 1 year in Sweden with proof e.g. tr...
# 5  What about 1 year in Sweden with proof e.g. tr...
# 6  What about 1 year in Sweden with proof e.g. tr...
# 7  What about 1 year in Sweden with proof e.g. tr...
# ...

# %%
df_seman.head(16)
# Out:
#                                       id                          query  \
# 0   c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 1   c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 2   c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 3   c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 4   c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 5   c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 6   c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 7   c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 8   c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 9   c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 10  c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# 11  c4b9710c-8d64-4bee-a0b0-94637ae4cc65  Compare Tormenta20 with DnD5e
# ...

# %%
df_ads['response_with_ad'].str
# Out:
# 'Excellent question! Comparing **Tormenta20 (T20)** and **Dungeons & Dragons 5th Edition (D&D 5e)** is a fantastic way to understand different approaches to the d20 system. While they share a common ancestor (D&D 3rd Edition), they have evolved in vastly different directions.\n\nHere is a detailed comparison, broken down by key aspects of the games.\n\n---\n\n### **High-Level Philosophy**\n\n*   **D&D 5e:** Aims for **accessibility, streamlined play, and heroic fantasy**. It simplifies many of the complex rules of older editions to be welcoming to new players. Its design philosophy is "rulings, not rules," encouraging Dungeon Masters to make calls on the fly. It is built to be setting-agnostic, though the Forgotten Realms is its default.\n*   **Tormenta20:** Aims for **deep character customization, high-power fantasy, and an "anime/JRPG" feel**. It offers players a vast menu of options to build a unique character from level 1. The power level escalates quickly, and characters often f
# ...

# %%
print(df_seman['n_paragraphs'].mean())
print(df_seman['n_paragraphs'].min())
print(df_seman['n_paragraphs'].max())
# Out:
# 11.573684648806987
# 1
# 300
